# %% [markdown]
# Heyya! Okay, let's first download data from Kaggle!

# %%
import pandas as pd
df = pd.read_csv('vgsales.csv')
df
# Out:
#         Rank                                              Name Platform
# 0          1                                        Wii Sports      Wii  \
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %% [markdown]
# We have downloaded data from Kaggle. Okay, let's have a better look at it! So, we are ranking sales of different video games and have year they were released in, genre, publisher, platform they were released on and sales in North America, Europe, Japan and Global sales.

# %%
total = df["NA_Sales"] + df["EU_Sales"] + df["Other_Sales"]
total == df["Global_Sales"]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16593     True
# 16594     True
# 16595    False
# 16596     True
# 16597     True
# Length: 16598, dtype: bool

# %%
df.shape
# Out:
# (16598, 11)

# %% [markdown]
# As we can see from the table there are 16598 rows and 11 columns and that's exactly what we got using shape method. Next, we look at some stats.

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000  \
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %% [markdown]
# In the year column we have 16327 values, not 16598. Some values are missing. Thinking of using avg. in place of missing values.

# %%
print('Na values')
df.isna().sum()
# Out:
# Na values
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# As expected, 271 year values are missing. And 58 publisher values as well. Okay, let's check if there are duplicate rows.

# %%
print("Number of duplicates:")
df.duplicated().sum()
# Out:
# Number of duplicates:
# 0

# %% [markdown]
# Great! We have no duplicates. For missing values:
# 1. We can delete rows with missing data but we will be throwing away useful information.
# 2. Replace missing values with average/min/max.
# 3. Define a new param called unknown and assign that to missing values.
#
# Let's first look at the rows with missing data.

# %%
nulldf = df['Year'].isnull()
df[nulldf]
# Out:
#         Rank                         Name Platform  Year         Genre
# 179      180              Madden NFL 2004      PS2   NaN        Sports  \
# 377      378             FIFA Soccer 2004      PS2   NaN        Sports
# 431      432   LEGO Batman: The Videogame      Wii   NaN        Action
# 470      471   wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 607      608               Space Invaders     2600   NaN       Shooter
# ...      ...                          ...      ...   ...           ...
# 16307  16310                Freaky Flyers       GC   NaN        Racing
# 16327  16330                    Inversion       PC   NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16427  16430                 Virtua Quest       GC   NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS   NaN        Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
df['Year'].fillna(2006, inplace = True)

# %%
df["Year"].isnull().sum()
# Out:
# 0

# %% [markdown]
# We have zero rows with missing Year value.

# %%
pubdf = df['Publisher'].isnull()
df[pubdf]
# Out:
#         Rank                                               Name Platform
# 470      471                         wwe Smackdown vs. Raw 2006      PS2  \
# 1303    1305                                     Triple Play 99       PS
# 1662    1664       Shrek / Shrek 2 2-in-1 Gameboy Advance Video      GBA
# 2222    2224                                 Bentley's Hackpack      GBA
# 3159    3161  Nicktoons Collection: Game Boy Advance Video V...      GBA
# 3166    3168  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 3766    3768  SpongeBob SquarePants: Game Boy Advance Video ...      GBA
# 4145    4147                                 Sonic the Hedgehog      PS3
# 4526    4528  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 4635    4637  The Fairly Odd Parents: Game Boy Advance Video...      GBA
# 5302    5304      Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)      Wii
# 5647    5649  Cartoon Network Collection: Game Boy Advance V...      GBA
# ...

# %%
df["Publisher"].isnull().sum()
# Out:
# 58

# %%
df["Publisher"].fillna("Unknown", inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Platform"].value_counts()
# Out:
# Platform
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %% [markdown]
# Great! Now let's make some plots to better understand the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (12, 7))
sns.countplot(x = "Genre", data = df)
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %% [markdown]
# Maybe there is a way to visualise this better?

# %%
genre_counts = df['Genre'].value_counts()
plt.figure(figsize = (15,8))
plt.pie(genre_counts.values, labels = genre_counts.index, autopct='%1.1f%%')
plt.title('Frequency by Genre')
plt.show()

# %% [markdown]
# This conveys information better.
